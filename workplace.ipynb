# %%
from scripts.transformer import DataTransformer
import pandas as pd


df = pd.read_csv('./data/games.csv')

transformer = DataTransformer()

X = transformer.fit_transform(df)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# Ustawienie ziarna dla generatora liczb losowych
np.random.seed(42)

# Generowanie danych do liniowej regresji
X, y, coef = make_regression(n_samples=100, n_features=1, noise=10, coef=True)

# Wartość współczynnika nachylenia (slope)
slope = coef

# Wyraz wolny (intercept) - tu wpisz interesujący Cię wyraz wolny, jeśli potrzebujesz innego niż 0.
intercept = 0

# Wykres punktów danych
plt.scatter(X, y, label='Dane')

# Wykres prostej regresji
plt.plot(X, slope * X + intercept, color='red', label='Regresja liniowa')

plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50])

# Obliczenie współczynnika nachylenia (slope)
slope = np.cov(X, y, ddof=0)[0, 1] / np.var(X, ddof=0)

# Obliczenie wyrazu wolnego (intercept)
intercept = np.mean(y) - slope * np.mean(X)

plt.scatter(X, y, label='Dane')

# Wykres prostej regresji
plt.plot(X, slope * X + intercept, color='red', label='Regresja liniowa')

plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
['ES1', 'GB1', 'IT1', 'UKR1', 'BE1', 'FR1', 'TR1', 'RU1', 'DK1',
       'NL1', 'PO1', 'SC1', 'GR1', 'L1']

# %%
import pandas as pd

COL_TO_SEL = ['competition_id','home_club_name', 'season', 'home_club_id', 'home_club_position']

df = pd.read_csv('.\\data\\games.csv')
df = df.loc[df['season']==2022]
df = df.loc[df['competition_type']=='domestic_league']
df['date'] = pd.to_datetime(df['date'])

result_df = df.loc[df.groupby(['competition_id', 'home_club_id'])['date'].idxmax()]

final_df = result_df[COL_TO_SEL].sort_values('home_club_position')
json_data = final_df.to_json(orient='records')

# %%
json_data
# Out:
# '[{"competition_id":"ES1","home_club_name":"FC Barcelona","season":2022,"home_club_id":131,"home_club_position":1},{"competition_id":"GB1","home_club_name":"Manchester City","season":2022,"home_club_id":281,"home_club_position":1},{"competition_id":"IT1","home_club_name":"SSC Napoli","season":2022,"home_club_id":6195,"home_club_position":1},{"competition_id":"UKR1","home_club_name":"Shakhtar Donetsk","season":2022,"home_club_id":660,"home_club_position":1},{"competition_id":"BE1","home_club_name":"KRC Genk","season":2022,"home_club_id":1184,"home_club_position":1},{"competition_id":"FR1","home_club_name":"Paris Saint-Germain","season":2022,"home_club_id":583,"home_club_position":1},{"competition_id":"TR1","home_club_name":"Galatasaray","season":2022,"home_club_id":141,"home_club_position":1},{"competition_id":"RU1","home_club_name":"Zenit St. Petersburg","season":2022,"home_club_id":964,"home_club_position":1},{"competition_id":"DK1","home_club_name":"FC Nordsjaelland","season":2022,
# ...
